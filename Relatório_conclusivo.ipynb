# %% [markdown]
# <a href="https://colab.research.google.com/github/DevaFullStack/challenge_alura_store/blob/main/Relat%C3%B3rio_conclusivo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧾 Relatório de Análise de Desempenho das Lojas
#
# **Para: Senhor João**
#
# **De: DevaFullStack**
#
# **Data: 09/07/2025**
#
# **Assunto: Análise de Desempenho das Lojas e Recomendação para Venda**
#
# Senhor João,
#
# Em resposta à sua solicitação para analisar o desempenho de suas quatro lojas e recomendar qual delas seria a melhor opção para venda, realizamos uma análise detalhada dos dados de vendas, faturamento, avaliação e outros indicadores-chave. Nosso objetivo foi identificar a loja com o menor rendimento geral para auxiliar sua decisão de investimento futuro.
#
# Apresentamos a seguir os principais achados e a nossa recomendação.
#
# ---

# %% [markdown]
# # 🧾 Relatório de Análise de Desempenho das Lojas
#
# **Para: Senhor João**
#
# **De: DevaFullStack**
#
# **Data: 09/07/2025**
#
# **Assunto: Análise de Desempenho das Lojas e Recomendação para Venda**
#
# Senhor João,
#
# Em resposta à sua solicitação para analisar o desempenho de suas quatro lojas e recomendar qual delas seria a melhor opção para venda, este relatório apresenta um resumo das métricas de desempenho calculadas e oferece uma recomendação sobre qual loja pode ser considerada para venda, de acordo com os objetivos propostos.
#
# ### Sumário das Métricas Analisadas:
#
# Consideramos as seguintes métricas chave para a avaliação de cada loja:
#
# - **Faturamento Total:** O valor total das vendas realizadas por cada loja.
# - **Faturamento Mensal:** A evolução do faturamento ao longo do tempo, permitindo identificar sazonalidades e tendências.
# - **Vendas por Categoria:** A distribuição do faturamento entre as diferentes categorias de produtos em cada loja.
# - **Avaliação Média dos Clientes:** A satisfação geral dos clientes com base nas avaliações das compras.
# - **Produtos Mais e Menos Vendidos:** Identificação dos produtos de maior e menor saída em cada unidade.
# - **Frete Médio:** O custo médio do frete por loja.
# - **Análise Geográfica:** Visualização da distribuição espacial das vendas.
#
# ### Análise dos Resultados:
#
# #### Faturamento Total
#
# A análise do faturamento total revela o desempenho bruto de cada loja:

# %% [markdown]
# Conforme os gráfico a seguir, a Loja 1 apresenta o maior faturamento total, seguida pela Loja 2, Loja 3 e Loja 4, respectivamente.![Faturamento por loja (barras).png](data:image/png;base64,...)
# ![Participação percentual no faturamento total (pizza).png](data:image/png;base64,...)

# %% [markdown]
# #### Faturamento Mensal
#
# A análise mensal do faturamento permite observar as tendências e sazonalidades.

# %% [markdown]
# Os gráficos de faturamento mensal mostram a evolução do desempenho de cada loja ao longo do tempo.
# ![Faturamento Mensal por Loja.png](data:image/png;base64,...)
# ![Gráfico de barras agrupadas para visualizar o faturamento mensal.png](data:image/png;base64,...)

# %% [markdown]
# #### Distribuição das Vendas por Categoria
#
# A distribuição das vendas por categoria indica quais produtos são mais populares em cada loja.
#
# ![gráfico de barras para visualizar as categorias.png](data:image/png;base64,...)
#
# ![Gráfico de Barras Agrupadas para o Faturamento por Categoria nas Lojas.png](data:image/png;base64,...)
#
# ![Gráfico de Heatmap para o Faturamento por Categoria nas Lojas.png](data:image/png;base64,...)

# %% [markdown]
# #### Avaliação Média por Loja
#
# A avaliação média reflete a satisfação dos clientes.
#
# ![Gráfico de Barras Verticais da Média de Avaliação.png](data:image/png;base64,...)

# %% [markdown]
# #### Produtos Mais e Menos Vendidos por Loja
#
# A análise dos produtos mais e menos vendidos oferece insights sobre o desempenho do inventário.
#
# ![Gráfico de Dispersão da Contagem de Vendas de Produtos por Loja.png](data:image/png;base64,...)![Gráficos de Barras dos 3 Produtos Mais Vendidos por Loja.png](data:image/png;base64,...)

# %% [markdown]
# #### Frete Médio por Loja
#
# O frete médio indica o custo de entrega para cada unidade.
#
# ![Gráfico de Barras Verticais do Frete Médio por Loja.png](data:image/png;base64,...)![Gráfico de Pizza da Participação Percentual no Frete Total por Loja.png](data:image/png;base64,...)

# %% [markdown]
# #### Análise Geográfica das Vendas
#
# A distribuição geográfica das vendas pode revelar padrões regionais.
#
# ![Gráfico de Dispersão das Vendas por Localização.png](data:image/png;base64,...)

# %% [markdown]
# ### Recomendação
#
# Com base na análise das métricas, podemos observar os seguintes pontos:
#
# *   **Faturamento Total:** A Loja 4 apresenta o menor faturamento total.
# *   **Faturamento Mensal:** A Loja 4 demonstra um faturamento consistentemente menor ao longo do tempo em comparação com as outras lojas.
# *   **Avaliação Média:** A Loja 4 tem a menor avaliação média, indicando uma menor satisfação dos clientes.
# *   **Frete Médio:** A Loja 4 possui o menor frete médio, o que pode ser um ponto positivo, mas não compensa o menor faturamento e avaliação.
# *   **Produtos Vendidos:** A análise de produtos mais e menos vendidos pode indicar que a Loja 4 tem produtos de menor saída ou uma demanda diferente das outras lojas.
# *   **Análise Geográfica:** A distribuição geográfica das vendas da Loja 4 pode ser menos densa ou concentrada em áreas com menor potencial de compra em comparação com as outras lojas.
#
# Considerando o objetivo de vender a loja com o pior desempenho geral, a **Loja 4** se destaca como a candidata mais provável com base nas métricas analisadas, apresentando o menor faturamento total e mensal, a menor avaliação média dos clientes e uma distribuição de vendas possivelmente menos favorável.
#
# É importante ressaltar que a decisão final deve levar em conta outros fatores estratégicos e de mercado que podem não estar representados neste conjunto de dados.
#
# Este relatório fornece uma base analítica sólida para auxiliar o Senhor João em sua decisão.
